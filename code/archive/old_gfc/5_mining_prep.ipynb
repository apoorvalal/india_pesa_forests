# %%
import os, sys, glob
import re

from pathlib import Path
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
font = {'family' : 'IBM Plex Sans',
        'weight' : 'normal',
        'size'   : 10}
plt.rc('font', **font)


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# parallel
from multiprocessing import Pool
from joblib import Parallel, delayed

# geo
import geopandas as gpd
import rtree
from shapely.geometry import shape, mapping, Point, LinearRing

# %%
home_root = '/home/alal/Dropbox/1_Research/India_Forests'
yen_root  = '/home/users/apoorval/Research/India_Forests'
root = Path(home_root)

# %%
code = root / 'Code'
data = root / 'Data'
dataout = '/home/alal/Dropbox/1_Research/india_pesa_forests/inp/'
spatial = data / 'Spatial'

# %% [markdown]
# # Mining Atlas

# %%
# %%time 
vil = pd.read_csv(data / 'Intermediate/villages_points_all2.csv')
vil_g = gpd.GeoDataFrame(vil, geometry=gpd.points_from_xy(vil.lon, vil.lat))
# Out:
# <string>:2: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
# CPU times: user 9.09 s, sys: 998 ms, total: 10.1 s
# Wall time: 10.2 s

# %%
df = pd.read_stata(root/'Data/Admin/india-mines/atlas_clean.dta')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2546 entries, 0 to 2545
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   metal_class     2546 non-null   object
#  1   mineral         2546 non-null   object
#  2   state           2546 non-null   object
#  3   sheet_no        2546 non-null   object
#  4   district        2546 non-null   object
#  5   locality        2546 non-null   object
#  6   latlong         2546 non-null   object
#  7   symbol          2546 non-null   object
#  8   rock_type       2546 non-null   object
#  9   rock_age        2546 non-null   object
#  10  deposit_size    2546 non-null   int8
#  11  remark          2546 non-null   object
#  12  page            2546 non-null   float32
#  13  latitude        2546 non-null   float32
#  14  longitude       2546 non-null   float32
#  15  gsi_deposit_id  2546 non-null   float32
# dtypes: float32(4), int8(1), object(11)
# memory usage: 281.0+ KB

# %%
df.head()
# Out:
#                    metal_class   mineral            state sheet_no  \
# 0  Iron and Ferro-Alloy Metals  chromite  ANDAMAN ISLANDS      24a
# 1  Iron and Ferro-Alloy Metals  chromite  ANDAMAN ISLANDS      24a
# 2  Iron and Ferro-Alloy Metals  chromite  ANDAMAN ISLANDS      24a
# 3  Iron and Ferro-Alloy Metals  chromite   ANDHRA PRADESH       18
# 4  Iron and Ferro-Alloy Metals  chromite   ANDHRA PRADESH       18
#
#          district                        locality          latlong symbol  \
# 0   North Andaman                  34. Khalighati  13^07' : 92^58'     Cr
# 1   South Andaman  35. Beadonabad and Chidiyatapu  11^32' : 92^43'     Cr
# 2  Rutland Island                36. Port Man Bay  11^22' : 92^40'     Cr
# 3   Khammam dist.                 37. Linganapeta  17^15' : 80^25'     Cr
# 4   Khammam dist.                38. Shriranigiri  17^20' : 80^24'     Cr
#
#                                            rock_type  rock_age  deposit_size  \
# 0                                          Ophiolite  Mesozoic             1
# 1                                          Ophiolite  Mesozoic             1
# 2                                          Ophiolite  Mesozoic             3
# 3  Ultramafic intrusion in Peninsular Gneissic Co...  Mesozoic             3
# 4  Ultramafic intrusion in Peninsular Gneissic Co...  Mesozoic             3
#
#                                       remark  page   latitude  longitude  \
# 0                                              1.0  13.116667  92.966667
# 1                                              1.0  11.533334  92.716667
# 2                                              1.0  11.366667  92.666664
# 3  Khammam-Krishna Chromite Belt No 37,38,40   1.0  17.250000  80.416664
# 4                                              1.0  17.333334  80.400002
#
#    gsi_deposit_id
# 0             1.0
# 1             2.0
# 2             3.0
# 3             4.0
# 4             5.0

# %%
(df[['metal_class', 'locality']].groupby('locality')
    .count().sort_values(by = 'metal_class', ascending = False)
)
# Out:
#                                   metal_class
# locality
# 2. Kaliapani                                2
# 6. Akwali                                   2
# 288. Barora-Chuli                           2
# 5. Gopalpura area                           2
# 46. Karanjia                                1
# ...                                       ...
# 209. Balembhija                             1
# 209. Kodwa                                  1
# 21. Amlirang area                           1
# 21. Baula-Nausahi Phuljhari area            1
# Yellambaile                                 1
#
# [2542 rows x 1 columns]

# %%
dropminerals = ['limestone', 'fire clay', 'clay', 'quartz glass/silica sand',
                'mica', 'ochre', 'talc', 'gypsum', 'salt']
df2 = df.loc[~df.mineral.isin(dropminerals)]

# %%
df.shape
df2.shape
# Out:
# (2546, 16)
# (1389, 16)

# %%
df2.metal_class.value_counts()
df2.mineral.value_counts()
# Out:
# BASE METALS, LIGHT METALS AND PRECIOUS METALS                 560
# Iron and Ferro-Alloy Metals                                   427
# CHEMICAL-FERTILISER AND CERAMIC-REFRACTORY MINERALS           274
# OTHER INDUSTRIAL MINERALS, MINERAL FUEL AND PRECIOUS STONE    128
# Name: metal_class, dtype: int64
# bauxite        263
# copper         173
# hematite       166
# dolomite       124
# manganese      119
# magnetite       69
# coal            55
# gold            52
# asbestos        45
# lead            43
# chromite        40
# magnesite       32
# barite          25
# graphite        18
# phosphorite     15
# diamond         14
# tungsten        14
# titanium        14
# sillimanite     13
# feldspar        12
# potash           9
# apatite          9
# vermiculite      8
# nickel           8
# kyanite          7
# cobalt           6
# lignite          6
# pyrite           6
# zinc             5
# molybdenum       5
# tin              5
# fluorite         3
# mercury          2
# silver           2
# sulphur          1
# antimony         1
# Name: mineral, dtype: int64

# %% [markdown]
# ## Convert to Geodata

# %%
mines = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
mines.mineral.nunique()
# Out:
# 45

# %%
top20 = mines.mineral.value_counts().nlargest(20).index

# %% [markdown]
# # Maps

# %%
states = gpd.read_file("/home/alal/Dropbox/_Data/India_spatial_pipeline/data/ADM/IND_adm1.shp")

# %%
f, ax = plt.subplots(1,figsize = (10, 12), dpi = 200)
states.plot(facecolor = 'None',linewidth = 0.5, edgecolor = 'k', ax = ax)
mines.loc[mines.mineral.isin(top20)].plot(column = 'mineral', categorical = True, 
            markersize = 0.8 , ax = ax,
            legend = True, cmap = 'tab20',
            legend_kwds = {
                'loc': 'lower right', 'markerscale': 0.3, 'ncol': 2,
                'prop': {'size': 10}})
ax.set_axis_off()
ax.set_title("Locations of Mines in India \n 20 most common minerals \n State borders overlaid")
f.savefig(root/'out/mine_map.pdf')
# Out:
# Text(0.5, 1.0, 'Locations of Mines in India \n 20 most common minerals \n State borders overlaid')

# %% [markdown]
# ### Iron

# %%
iron = mines.query('metal_class == "Iron and Ferro-Alloy Metals"')
iron.shape
# Out:
# (427, 17)

# %%
f, ax = plt.subplots(1,figsize = (10, 12), dpi = 200)
states.plot(facecolor = 'None',linewidth = 0.5, edgecolor = 'k', ax = ax)
iron.plot(column = 'mineral', categorical = True, 
            markersize = 0.8 , ax = ax,
            legend = True, cmap = 'tab20',
            legend_kwds = {
                'loc': 'lower right', 'markerscale': 0.3, 'ncol': 2,
                'prop': {'size': 10}})
ax.set_axis_off()
ax.set_title("Locations of Iron Mines in India \n State borders overlaid")
f.savefig(root/'out/iron_mine_map.pdf')
# Out:
# Text(0.5, 1.0, 'Locations of Iron Mines in India \n State borders overlaid')

# %% [markdown]
# # Distance to Mines computation

# %% [markdown]
# ## Distance Computation - overall

# %%
index = rtree.index.Index()
for ind, row in mines.iterrows():
    geom1 = shape(row['geometry'])
    index.insert(ind, geom1.bounds)

# %%
nearest_segment     = lambda x: list(index.nearest(x.bounds, 1))[0]
distance_to_nearest = lambda x: mines.distance(x).min()

# %%
# %%time
vil_g['min_dist_to_mine'] = vil_g.geometry.apply(distance_to_nearest)
vil_g['nearest_mine_id']  = vil_g.geometry.apply(nearest_segment)

# %%
Client().send_message("Mine Distance Computation done")

# %%
sns.distplot(vil_g.min_dist_to_mine)

# %% [markdown]
# ### By mineral

# %%
minerals = mines.mineral.unique()

# %%
def distance_compute(m):
    mines_subset = mines.loc[mines.mineral == m]
    distance_to_mine = lambda x: mines_subset.distance(x).min()
    d = vil_g.geometry.apply(distance_to_mine)

# %%
# %%time
distances = Parallel(n_jobs = 10, verbose = 50)(delayed(
    distance_compute)(m) for m in minerals
    )
Client().send_message("Mineral-wise distance Computation done")
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   1 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=10)]: Done   2 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=10)]: Done   3 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=10)]: Done   4 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=10)]: Done   5 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=10)]: Done   6 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=10)]: Done   7 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=10)]: Done   8 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=10)]: Done   9 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=10)]: Done  10 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=10)]: Done  11 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=10)]: Done  12 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=10)]: Done  13 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=10)]: Done  14 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=10)]: Done  15 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=10)]: Done  16 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=10)]: Done  17 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=10)]: Done  18 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=10)]: Done  19 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=10)]: Done  20 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=10)]: Done  22 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=10)]: Done  23 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=10)]: Done  24 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=10)]: Done  25 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=10)]: Done  26 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=10)]: Done  27 out of  45 | elapsed: 12.7min remaining:  8.4min
# [Parallel(n_jobs=10)]: Done  28 out of  45 | elapsed: 13.3min remaining:  8.1min
# [Parallel(n_jobs=10)]: Done  29 out of  45 | elapsed: 13.7min remaining:  7.6min
# [Parallel(n_jobs=10)]: Done  30 out of  45 | elapsed: 13.8min remaining:  6.9min
# [Parallel(n_jobs=10)]: Done  31 out of  45 | elapsed: 14.9min remaining:  6.7min
# [Parallel(n_jobs=10)]: Done  32 out of  45 | elapsed: 15.7min remaining:  6.4min
# [Parallel(n_jobs=10)]: Done  33 out of  45 | elapsed: 15.9min remaining:  5.8min
# [Parallel(n_jobs=10)]: Done  34 out of  45 | elapsed: 16.1min remaining:  5.2min
# [Parallel(n_jobs=10)]: Done  35 out of  45 | elapsed: 17.3min remaining:  4.9min
# [Parallel(n_jobs=10)]: Done  36 out of  45 | elapsed: 17.4min remaining:  4.3min
# [Parallel(n_jobs=10)]: Done  37 out of  45 | elapsed: 17.7min remaining:  3.8min
# [Parallel(n_jobs=10)]: Done  38 out of  45 | elapsed: 18.3min remaining:  3.4min
# [Parallel(n_jobs=10)]: Done  39 out of  45 | elapsed: 19.1min remaining:  2.9min
# [Parallel(n_jobs=10)]: Done  40 out of  45 | elapsed: 19.3min remaining:  2.4min
# [Parallel(n_jobs=10)]: Done  41 out of  45 | elapsed: 20.1min remaining:  2.0min
# [Parallel(n_jobs=10)]: Done  42 out of  45 | elapsed: 20.5min remaining:  1.5min
# [Parallel(n_jobs=10)]: Done  43 out of  45 | elapsed: 20.7min remaining:   57.9s
# [Parallel(n_jobs=10)]: Done  45 out of  45 | elapsed: 41.9min remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  45 out of  45 | elapsed: 41.9min finished
# CPU times: user 5min 51s, sys: 6.02 s, total: 5min 57s
# Wall time: 41min 52s

# %% [markdown]
# ### collate and write

# %%
distances_df = pd.concat(distances, axis = 1)
distances_df.columns = ['min_dist_to_' + re.sub("( |/)", "", m) for m in minerals]

# %%
vil2 = pd.concat([vil_g, distances_df], axis = 1)

# %% [markdown]
# ### Write

# %%
vil2 = pd.DataFrame(vil2.drop('geometry', axis = 1))

# %%
vil2.to_csv(data/"Intermediate/village_points_all_mines.csv")

# %% [markdown]
# # Intensive margin - count number of mines in buffer

# %% [markdown]
# ## 5 km

# %%
sindex = mines.sindex
len(sindex.leaves())
# Out:
# 37

# %%
# %%time 
results_list = []
# iterate over the points
for index, row in vil_g.iterrows():
    buffer = row['geometry'].buffer(0.05)  # buffer
    # find approximate matches with r-tree, then precise matches from those approximate ones
    possible_matches_index = list(sindex.intersection(buffer.bounds))
    possible_matches = mines.iloc[possible_matches_index]
    precise_matches = possible_matches[possible_matches.intersects(buffer)]
    results_list.append(len(precise_matches))
# Out:
# CPU times: user 10min 48s, sys: 453 ms, total: 10min 49s
# Wall time: 10min 49s

# %%
results_list[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
vil_g['mines_in_5k'] = pd.Series(results_list)

# %%
sns.distplot(vil_g.mines_in_5k)
# Out:
# /home/alal/anaconda3/envs/gds/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
vil_g.mines_in_5k.describe()
# Out:
# count    308503.000000
# mean          0.094339
# std           0.457595
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          14.000000
# Name: mines_in_5k, dtype: float64

# %% [markdown]
# ## 10 km

# %%
# %%time 
results_list = []
# iterate over the points
for index, row in vil_g.iterrows():
    buffer = row['geometry'].buffer(0.1)  # buffer
    # find approximate matches with r-tree, then precise matches from those approximate ones
    possible_matches_index = list(sindex.intersection(buffer.bounds))
    possible_matches = mines.iloc[possible_matches_index]
    precise_matches = possible_matches[possible_matches.intersects(buffer)]
    results_list.append(len(precise_matches))
# Out:
# CPU times: user 11min 20s, sys: 584 ms, total: 11min 20s
# Wall time: 11min 20s

# %%
results_list[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
vil_g['mines_in_10k'] = pd.Series(results_list)

# %%
sns.distplot(vil_g.mines_in_10k)
# Out:
# /home/alal/anaconda3/envs/gds/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
vil_g.mines_in_10k.describe()
# Out:
# count    308503.000000
# mean          0.380881
# std           1.179393
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          31.000000
# Name: mines_in_10k, dtype: float64

# %% [markdown]
# ## 50 km

# %%
# %%time 
results_list = []
# iterate over the points
for index, row in vil_g.iterrows():
    buffer = row['geometry'].buffer(0.5)  # buffer
    # find approximate matches with r-tree, then precise matches from those approximate ones
    possible_matches_index = list(sindex.intersection(buffer.bounds))
    possible_matches = mines.iloc[possible_matches_index]
    precise_matches = possible_matches[possible_matches.intersects(buffer)]
    results_list.append(len(precise_matches))
# Out:
# CPU times: user 16min 38s, sys: 500 ms, total: 16min 38s
# Wall time: 16min 38s

# %%
results_list[:5]
# Out:
# [46, 69, 53, 60, 82]

# %%
vil_g['mines_in_50k'] = pd.Series(results_list)

# %%
sns.distplot(vil_g.mines_in_50k)

# %%
vil_g.mines_in_50k.describe()
# Out:
# count    308503.000000
# mean          9.601625
# std          12.030114
# min           0.000000
# 25%           1.000000
# 50%           5.000000
# 75%          14.000000
# max         106.000000
# Name: mines_in_50k, dtype: float64

# %%
# %%time 
results_list = []
# iterate over the points
for index, row in vil_g.iterrows():
    buffer = row['geometry'].buffer(0.1)  # buffer
    # find approximate matches with r-tree, then precise matches from those approximate ones
    possible_matches_index = list(sindex.intersection(buffer.bounds))
    possible_matches = mines.iloc[possible_matches_index]
    precise_matches = possible_matches[possible_matches.intersects(buffer)]
    results_list.append(len(precise_matches))
# Out:
# CPU times: user 11min 20s, sys: 584 ms, total: 11min 20s
# Wall time: 11min 20s

# %%
results_list[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
vil_g['mines_in_10k'] = pd.Series(results_list)

# %%
sns.distplot(vil_g.mines_in_10k)
# Out:
# /home/alal/anaconda3/envs/gds/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
vil_g.mines_in_10k.describe()
# Out:
# count    308503.000000
# mean          0.380881
# std           1.179393
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          31.000000
# Name: mines_in_10k, dtype: float64

# %%
# %%time
pd.DataFrame(vil_g.drop('geometry', axis = 1)).to_csv(data/"Intermediate/village_points_mine_counts.csv")
# Out:
# CPU times: user 32.7 s, sys: 844 ms, total: 33.5 s
# Wall time: 33.6 s

# %% [markdown]
# # Map v2 with village points

# %%
states = gpd.read_file("/home/alal/Dropbox/_Data/India_spatial_pipeline/data/ADM/IND_adm1.shp")

# %%
f, ax = plt.subplots(1,figsize = (10, 12), dpi = 200)
states.plot(facecolor = 'None',linewidth = 0.5, edgecolor = 'k', ax = ax)
vil_g.plot(column = 'mines_in_10k',  markersize = 0.5 , ax = ax, cmap = 'viridis')
mines.loc[mines.mineral.isin(top20)].plot(column = 'mineral', categorical = True, 
            markersize = 0.8 , ax = ax,
            cmap = 'tab20')
ax.set_axis_off()
ax.set_title("Villages with Mine Proximity \n Number of mines within 10 km radius \n State borders overlaid")
# Out:
# Text(0.5, 1.0, 'Villages with Mine Proximity \n Number of mines within 10 km radius \n State borders overlaid')

# %%
f.savefig(root/'out/mine_density_map.pdf')

f.savefig(root/'out/mine_density_map.png')
