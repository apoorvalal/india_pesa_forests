# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

from pathlib import Path

from rasterstats import zonal_stats
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import glob, os
# run for jupyter notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Out:
# /home/alal/anaconda3/envs/gds/lib/python3.7/site-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
from joblib import Parallel, delayed
import functools

# %% [markdown]
# ### Folder Structure

# %%
#%% Read in data
rice_root = '/home/apoorval/Research/GeoSpatial/India_Forests/'
dbox_root = '/home/alal/res/india_pesa_forests/'
root = Path(dbox_root)
data = root / 'inp'
spatial = data/'spatial'

# %% [markdown]
# # Polygon prep

# %%
# %%time
vil_treat = gpd.read_parquet(spatial/"Village_stack_treatment.spq")
vil_treat.head()

# %%
# %%time
vil_mcols = vil_treat[['STATE_UT', 'CODE_2011', 'geometry']].dissolve(by="CODE_2011")

# %%
vil_mcols.groupby(['CODE_2011']).size().value_counts()
vil_mcols.set_index("CODE_2011", inplace = True)
vil_mcols.to_parquet(root/"tmp/vil_to_merge.spq")

# %% [markdown]
# # Dry Run

# %%
vil_mcols = gpd.read_parquet(root/"tmp/vil_to_merge.spq")

# %%
vcf_rasters = glob.glob(str(root/"inp/**/*.tif"), recursive = True)
vcf_rasters[:5]
# Out:
# ['/home/alal/res/india_pesa_forests/inp/VCF_Rasters/VCF5KYR_1982001_001_2018224204211.tif',
#  '/home/alal/res/india_pesa_forests/inp/VCF_Rasters/VCF5KYR_2001001_001_2018224205557.tif',
#  '/home/alal/res/india_pesa_forests/inp/VCF_Rasters/VCF5KYR_1984001_001_2018224204542.tif',
#  '/home/alal/res/india_pesa_forests/inp/VCF_Rasters/VCF5KYR_1988001_001_2018224204838.tif',
#  '/home/alal/res/india_pesa_forests/inp/VCF_Rasters/VCF5KYR_2015001_001_2018224210248.tif']

# %%
rast = rasterio.open(vcf_rasters[0])

# %%
show((rast, 1), cmap = "viridis")
show((rast, 2), cmap = "viridis")
show((rast, 3), cmap = "viridis")
# Out:
# <AxesSubplot:>
# <AxesSubplot:>
# <AxesSubplot:>

# %% [markdown]
# ## reproject village data before zonal stats

# %%
# %%time
vil_reprojected = vil_mcols.to_crs(rast.crs.data)
vil_reprojected.crs
# Out:
# CPU times: user 3.43 s, sys: 503 ms, total: 3.94 s
# Wall time: 3.94 s
# <Geographic 2D CRS: +proj=longlat +ellps=clrk66 +no_defs +type=crs>
# Name: unknown
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - undefined
# Datum: Unknown based on Clarke 1866 ellipsoid
# - Ellipsoid: Clarke 1866
# - Prime Meridian: Greenwich

# %% [markdown]
# ## zonal stats func

# %%
def vil_zonal_stats(fp, polygons = vil_reprojected,
                    stat = ['min', 'max', 'mean', 'median', 'majority']):
    name = fp.split("/")[-1].split(".")[0][8:12]
    rast = rasterio.open(fp)
    array = rast.read(1)
    # Get the affine
    affine = rast.transform
    gdf1 = gpd.GeoDataFrame.from_features(
                zonal_stats(polygons, array, affine=affine,
                geojson_out = True, nodata = -1, stats = stat)
            )
    gdf1.index = vil_mcols.index
    remaps = dict(zip(stat, [s + "_" + name for s in stat]))
    gdf1.rename(remaps, axis = 1, inplace = True)
    gdf1.drop("geometry", axis = 1, inplace = True)
    return gdf1
# %%

# %%
# %%time
df = vil_zonal_stats(vcf_rasters[0])
# df.head()
# Out:
# CPU times: user 5min 51s, sys: 6.18 s, total: 5min 57s
# Wall time: 5min 57s

# %%
df.mean_1982.describe()
df.mean_1982.isna().value_counts()
# Out:
# count    52857.000000
# mean         3.166538
# std          5.275302
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          3.000000
# max         77.000000
# Name: mean_1982, dtype: float64
# True     251932
# False     52857
# Name: mean_1982, dtype: int64

# %% [markdown]
# ## Raster Merge

# %%
# %%time
list_cov_gdf = Parallel(n_jobs=3)(delayed(vil_zonal_stats)(f) for f in vcf_rasters)

# %%
# %%time
forest_cols = functools.reduce(lambda x, y: pd.merge(x, y,
        left_index = True, right_index = True),
    list_cov_gdf)
# Out:
# CPU times: user 3.76 s, sys: 128 ms, total: 3.89 s
# Wall time: 3.9 s

# %%
forest_cols.info(max_cols = 200)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 304789 entries, 0202300083006673 to 3463405908804035
# Data columns (total 192 columns):
#  #    Column         Non-Null Count   Dtype
# ---   ------         --------------   -----
#  0    STATE_UT_x     304789 non-null  object
#  1    min_1982       52857 non-null   float64
#  2    max_1982       52857 non-null   float64
#  3    mean_1982      52857 non-null   float64
#  4    median_1982    52857 non-null   float64
#  5    majority_1982  52857 non-null   float64
#  6    STATE_UT_y     304789 non-null  object
#  7    min_2001       52857 non-null   float64
#  8    max_2001       52857 non-null   float64
#  9    mean_2001      52857 non-null   float64
#  10   median_2001    52857 non-null   float64
#  11   majority_2001  52857 non-null   float64
#  12   STATE_UT_x     304789 non-null  object
#  13   min_1984       52857 non-null   float64
#  14   max_1984       52857 non-null   float64
#  15   mean_1984      52857 non-null   float64
#  16   median_1984    52857 non-null   float64
#  17   majority_1984  52857 non-null   float64
#  18   STATE_UT_y     304789 non-null  object
#  19   min_1988       52857 non-null   float64
#  20   max_1988       52857 non-null   float64
#  21   mean_1988      52857 non-null   float64
#  22   median_1988    52857 non-null   float64
#  23   majority_1988  52857 non-null   float64
#  24   STATE_UT_x     304789 non-null  object
#  25   min_2015       52857 non-null   float64
#  26   max_2015       52857 non-null   float64
#  27   mean_2015      52857 non-null   float64
#  28   median_2015    52857 non-null   float64
#  29   majority_2015  52857 non-null   float64
#  30   STATE_UT_y     304789 non-null  object
#  31   min_2007       52857 non-null   float64
#  32   max_2007       52857 non-null   float64
#  33   mean_2007      52857 non-null   float64
#  34   median_2007    52857 non-null   float64
#  35   majority_2007  52857 non-null   float64
#  36   STATE_UT_x     304789 non-null  object
#  37   min_1992       52857 non-null   float64
#  38   max_1992       52857 non-null   float64
#  39   mean_1992      52857 non-null   float64
#  40   median_1992    52857 non-null   float64
#  41   majority_1992  52857 non-null   float64
#  42   STATE_UT_y     304789 non-null  object
#  43   min_1997       52857 non-null   float64
#  44   max_1997       52857 non-null   float64
#  45   mean_1997      52857 non-null   float64
#  46   median_1997    52857 non-null   float64
#  47   majority_1997  52857 non-null   float64
#  48   STATE_UT_x     304789 non-null  object
#  49   min_1991       52857 non-null   float64
#  50   max_1991       52857 non-null   float64
#  51   mean_1991      52857 non-null   float64
#  52   median_1991    52857 non-null   float64
#  53   majority_1991  52857 non-null   float64
#  54   STATE_UT_y     304789 non-null  object
#  55   min_1983       52857 non-null   float64
#  56   max_1983       52857 non-null   float64
#  57   mean_1983      52857 non-null   float64
#  58   median_1983    52857 non-null   float64
#  59   majority_1983  52857 non-null   float64
#  60   STATE_UT_x     304789 non-null  object
#  61   min_1995       52857 non-null   float64
#  62   max_1995       52857 non-null   float64
#  63   mean_1995      52857 non-null   float64
#  64   median_1995    52857 non-null   float64
#  65   majority_1995  52857 non-null   float64
#  66   STATE_UT_y     304789 non-null  object
#  67   min_1990       52857 non-null   float64
#  68   max_1990       52857 non-null   float64
#  69   mean_1990      52857 non-null   float64
#  70   median_1990    52857 non-null   float64
#  71   majority_1990  52857 non-null   float64
#  72   STATE_UT_x     304789 non-null  object
#  73   min_2012       52857 non-null   float64
#  74   max_2012       52857 non-null   float64
#  75   mean_2012      52857 non-null   float64
#  76   median_2012    52857 non-null   float64
#  77   majority_2012  52857 non-null   float64
#  78   STATE_UT_y     304789 non-null  object
#  79   min_1996       52857 non-null   float64
#  80   max_1996       52857 non-null   float64
#  81   mean_1996      52857 non-null   float64
#  82   median_1996    52857 non-null   float64
#  83   majority_1996  52857 non-null   float64
#  84   STATE_UT_x     304789 non-null  object
#  85   min_2009       52857 non-null   float64
#  86   max_2009       52857 non-null   float64
#  87   mean_2009      52857 non-null   float64
#  88   median_2009    52857 non-null   float64
#  89   majority_2009  52857 non-null   float64
#  90   STATE_UT_y     304789 non-null  object
#  91   min_2005       52857 non-null   float64
#  92   max_2005       52857 non-null   float64
#  93   mean_2005      52857 non-null   float64
#  94   median_2005    52857 non-null   float64
#  95   majority_2005  52857 non-null   float64
#  96   STATE_UT_x     304789 non-null  object
#  97   min_2013       52857 non-null   float64
#  98   max_2013       52857 non-null   float64
#  99   mean_2013      52857 non-null   float64
#  100  median_2013    52857 non-null   float64
#  101  majority_2013  52857 non-null   float64
#  102  STATE_UT_y     304789 non-null  object
#  103  min_1986       52857 non-null   float64
#  104  max_1986       52857 non-null   float64
#  105  mean_1986      52857 non-null   float64
#  106  median_1986    52857 non-null   float64
#  107  majority_1986  52857 non-null   float64
#  108  STATE_UT_x     304789 non-null  object
#  109  min_2016       52857 non-null   float64
#  110  max_2016       52857 non-null   float64
#  111  mean_2016      52857 non-null   float64
#  112  median_2016    52857 non-null   float64
#  113  majority_2016  52857 non-null   float64
#  114  STATE_UT_y     304789 non-null  object
#  115  min_2006       52857 non-null   float64
#  116  max_2006       52857 non-null   float64
#  117  mean_2006      52857 non-null   float64
#  118  median_2006    52857 non-null   float64
#  119  majority_2006  52857 non-null   float64
#  120  STATE_UT_x     304789 non-null  object
#  121  min_2008       52857 non-null   float64
#  122  max_2008       52857 non-null   float64
#  123  mean_2008      52857 non-null   float64
#  124  median_2008    52857 non-null   float64
#  125  majority_2008  52857 non-null   float64
#  126  STATE_UT_y     304789 non-null  object
#  127  min_1987       52857 non-null   float64
#  128  max_1987       52857 non-null   float64
#  129  mean_1987      52857 non-null   float64
#  130  median_1987    52857 non-null   float64
#  131  majority_1987  52857 non-null   float64
#  132  STATE_UT_x     304789 non-null  object
#  133  min_1999       52857 non-null   float64
#  134  max_1999       52857 non-null   float64
#  135  mean_1999      52857 non-null   float64
#  136  median_1999    52857 non-null   float64
#  137  majority_1999  52857 non-null   float64
#  138  STATE_UT_y     304789 non-null  object
#  139  min_2002       52857 non-null   float64
#  140  max_2002       52857 non-null   float64
#  141  mean_2002      52857 non-null   float64
#  142  median_2002    52857 non-null   float64
#  143  majority_2002  52857 non-null   float64
#  144  STATE_UT_x     304789 non-null  object
#  145  min_2004       52857 non-null   float64
#  146  max_2004       52857 non-null   float64
#  147  mean_2004      52857 non-null   float64
#  148  median_2004    52857 non-null   float64
#  149  majority_2004  52857 non-null   float64
#  150  STATE_UT_y     304789 non-null  object
#  151  min_2014       52857 non-null   float64
#  152  max_2014       52857 non-null   float64
#  153  mean_2014      52857 non-null   float64
#  154  median_2014    52857 non-null   float64
#  155  majority_2014  52857 non-null   float64
#  156  STATE_UT_x     304789 non-null  object
#  157  min_1998       52857 non-null   float64
#  158  max_1998       52857 non-null   float64
#  159  mean_1998      52857 non-null   float64
#  160  median_1998    52857 non-null   float64
#  161  majority_1998  52857 non-null   float64
#  162  STATE_UT_y     304789 non-null  object
#  163  min_2010       52857 non-null   float64
#  164  max_2010       52857 non-null   float64
#  165  mean_2010      52857 non-null   float64
#  166  median_2010    52857 non-null   float64
#  167  majority_2010  52857 non-null   float64
#  168  STATE_UT_x     304789 non-null  object
#  169  min_1989       52857 non-null   float64
#  170  max_1989       52857 non-null   float64
#  171  mean_1989      52857 non-null   float64
#  172  median_1989    52857 non-null   float64
#  173  majority_1989  52857 non-null   float64
#  174  STATE_UT_y     304789 non-null  object
#  175  min_2003       52857 non-null   float64
#  176  max_2003       52857 non-null   float64
#  177  mean_2003      52857 non-null   float64
#  178  median_2003    52857 non-null   float64
#  179  majority_2003  52857 non-null   float64
#  180  STATE_UT_x     304789 non-null  object
#  181  min_1993       52857 non-null   float64
#  182  max_1993       52857 non-null   float64
#  183  mean_1993      52857 non-null   float64
#  184  median_1993    52857 non-null   float64
#  185  majority_1993  52857 non-null   float64
#  186  STATE_UT_y     304789 non-null  object
#  187  min_2011       52857 non-null   float64
#  188  max_2011       52857 non-null   float64
#  189  mean_2011      52857 non-null   float64
#  190  median_2011    52857 non-null   float64
#  191  majority_2011  52857 non-null   float64
# dtypes: float64(160), object(32)
# memory usage: 456.9+ MB

# %%
forest_cols.drop(["STATE_UT_x", "STATE_UT_y"], axis = 1, inplace = True)

# %%
forest_cols.to_csv(root/"tmp/forest_long_time_series.csv")

# %% [markdown]
# ## plot

# %%
import georasters as gr
from shapely.geometry import box

# %%
vil_w_forest = vil_reprojected.merge(forest_cols, left_index = True, right_index = True)
vil_w_forest.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 304789 entries, 0202300083006673 to 3463405908804035
# Columns: 162 entries, geometry to majority_2011
# dtypes: float64(160), geometry(1), object(1)
# memory usage: 387.1+ MB

# %%
# %%time
vil_w_forest = vil_w_forest.to_crs("epsg:4326")

# %%
vil_w_forest['mean_2001'] = vil_w_forest['mean_2001'].fillna(0)
jh = vil_w_forest.query("STATE_UT == 'Jharkhand'")

# %%
inpath = root/'inp/VCF_Rasters/VCF5KYR_2001001_001_2018224205557.tif'
rast = rasterio.open(str(inpath))

# %%
# %%time
outline = jh.dissolve(by = "STATE_UT")
# Out:
# CPU times: user 1min 29s, sys: 53.5 ms, total: 1min 29s
# Wall time: 1min 29s

# %%
bbox = box(outline.bounds)
# Out:
#               minx     miny      maxx      maxy
# STATE_UT
# Jharkhand  83.3319  21.9699  87.91917  25.34845

# %%
show((rast, 1), cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(1, 2, figsize = (10, 12), dpi = 120)
# polygon outline
# categorical polygon
jh.plot(column = 'mean_2001', 
                cmap = 'viridis', edgecolor = None, ax = ax[0]
             )
# title
ax[0].set_title("Forest Cover (VCF)\n Jharkhand, 2001")
# set axes off
ax[0].set_axis_off()



f.savefig(root/'tmp/jhar_map.pdf')
